# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-2*np.pi, 3*np.pi, 201)
plt.plot(x, 2*np.cos(x - 1) + 2)
plt.plot(x, 0.5*np.cos(x - 1) + 2)
plt.plot(x, 0.5*np.cos(x + 1) - 2)
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
